# %%
import os
import pydicom
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
ds = pydicom.dcmread(r'C:\Users\sriha\OneDrive\Desktop\Projects\PD_Project\PPMI\100001\DaT_Brain_Tomo\2020-09-09_17_07_33.0\I1449481\PPMI_100001_NM_DaT_Brain_Tomo_br_raw_20210601144217264_1_S1028880_I1449481.dcm')

new_image = ds.pixel_array[40].astype(float)

# %%
scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0

# %%
scaled_image = np.uint8(scaled_image)
final_image = Image.fromarray(scaled_image)

# %%
final_image.show()
