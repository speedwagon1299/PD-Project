# %%
import pydicom
import numpy as np
import os
import math
import pylab
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2 as cv
from keras.applications.vgg16 import VGG16, preprocess_input

# %%
file_path = r"C:\Users\sriha\OneDrive\Desktop\Projects\PD_Project\PPMI\No\PPMI\3000\Reconstructed_DaTSCAN\2011-01-20_16_28_47.0\I323662\PPMI_3000_NM_Reconstructed_DaTSCAN_Br_20120814154829508_1_S117534_I323662.dcm"

# %%
medical_image = pydicom.read_file(file_path)
print(medical_image)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 180
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Nuclear Medicine Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.16.124.113543.6006.99.1863271458386027096
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.16.124.113543.6006.99.7279597076940655221
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 470
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'RECON TOMO', 'EMISSION']
# (0008, 0014) Instance Creator UID                UI: 2.16.124.113543.6006.99.3020707999642196214
# (0008, 0016) SOP Class UID                       UI: Nuclear Medicine Image Storage
# ...

# %%
image = medical_image.pixel_array[40].astype(float)
# image = (np.maximum(image, 0) / image.max()) * 255.0
# image = np.uint8(image)
def preprocess_imgs(img, img_size):
    img = cv.resize(img, dsize=img_size, interpolation=cv.INTER_CUBIC)
    return np.array(img)
img = preprocess_imgs(image, (64,64))
print(image.shape)
plt.imshow(img)
# plt.show()
# plt.imshow(img, cmap = 'gray')
# plt.savefig(r"C:\Users\sriha\OneDrive\Desktop\Projects\PD_Project\PPMI\No\No_Final\No_1.png")
# Out:
# (109, 91)

# %%
print(image.min())
print(image.max())
# Out:
# 0
# 21
